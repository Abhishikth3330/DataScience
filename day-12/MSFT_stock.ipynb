# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('MSFT.csv')
data.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close    Volume
# 0  2020-10-20  215.800003  217.369995  ...  214.649994  212.698273  22753500
# 1  2020-10-21  213.119995  216.919998  ...  214.800003  212.846909  22724900
# 2  2020-10-22  213.929993  216.059998  ...  214.889999  212.936096  22351500
# 3  2020-10-23  215.029999  216.279999  ...  216.229996  214.263901  18879600
# 4  2020-10-26  213.850006  216.339996  ...  210.080002  208.169830  37111600
#
# [5 rows x 7 columns]

# %%
plt.figure(figsize=(10, 4))
plt.title('Microsoft Stock Prices')
plt.xlabel('Date')
plt.ylabel('Close')
plt.plot(data['Close'])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998351  0.998571  0.996472   0.996489 -0.342974
# High       0.998351  1.000000  0.998502  0.998574   0.998586 -0.328908
# Low        0.998571  0.998502  1.000000  0.998550   0.998561 -0.362807
# Close      0.996472  0.998574  0.998550  1.000000   0.999963 -0.351616
# Adj Close  0.996489  0.998586  0.998561  0.999963   1.000000 -0.351435
# Volume    -0.342974 -0.328908 -0.362807 -0.351616  -0.351435  1.000000

# %%
x = data[['Open', 'High', 'Low']]
y = data['Close']
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
data = pd.DataFrame(data={'Predicted Rate': ypred})
print(data.head())
# Out:
#    Predicted Rate
# 0      255.589996
# 1      204.720001
# 2      233.779999
# 3      266.690002
# 4      247.860001
