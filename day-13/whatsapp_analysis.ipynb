# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('country_vaccinations.csv')
data.head()
# Out:
#        country iso_code  ...                source_name            source_website
# 0  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 1  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 2  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 3  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 4  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
#
# [5 rows x 15 columns]

# %%
data.describe()
# Out:
#        total_vaccinations  ...  daily_vaccinations_per_million
# count        2.790000e+04  ...                    51056.000000
# mean         2.342338e+07  ...                     3528.110428
# std          1.318883e+08  ...                     4329.794805
# min          0.000000e+00  ...                        0.000000
# 25%          2.493890e+05  ...                      563.000000
# 50%          1.732574e+06  ...                     2229.000000
# 75%          8.851120e+06  ...                     5231.250000
# max          2.227334e+09  ...                   117497.000000
#
# [8 rows x 9 columns]

# %%
pd.to_datetime(data.date)
data.country.value_counts()
# Out:
# Denmark             317
# Norway              316
# Latvia              314
# England             310
# Scotland            310
#                    ...
# Haiti                87
# Pitcairn             85
# Falkland Islands     67
# Tanzania             57
# Niue                 43
# Name: country, Length: 222, dtype: int64

# %%
data = data[data.country.apply(lambda x: x not in ['England', 'Scotland', 'Wales', 'Northern Ireland'])]
data.country.value_counts()
# Out:
# Denmark             317
# Norway              316
# Latvia              314
# Canada              305
# United Kingdom      305
#                    ...
# Haiti                87
# Pitcairn             85
# Falkland Islands     67
# Tanzania             57
# Niue                 43
# Name: country, Length: 218, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech    6814
# Oxford/AstraZeneca                                               5106
# Oxford/AstraZeneca, Pfizer/BioNTech                              3059
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                     2815
# Oxford/AstraZeneca, Sinopharm/Beijing                            2733
#                                                                  ...
# Covaxin, Oxford/AstraZeneca                                       156
# Moderna, Oxford/AstraZeneca, Sinovac                              150
# Abdala, Soberana02                                                147
# Johnson&Johnson, Oxford/AstraZeneca, Sinovac                      142
# Johnson&Johnson                                                    57
# Name: vaccines, Length: 71, dtype: int64

# %%
df = data[['vaccines', 'country']]

# %%
df.head()
# Out:
#                                             vaccines      country
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan

# %%
dict_ = {}
for i in df.vaccines.unique():
    dict_[i] = [df['country'][j] for j in df[df['vaccines'] == i].index]

vaccines = {}
for key, value in dict_.items():
    vaccines[key] = set(value)

for i, j in vaccines.items():
    print(f"{i}:>>{j}")
# Out:
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Afghanistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Azerbaijan', 'Bosnia and Herzegovina', 'Oman', 'Albania'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Algeria', "Cote d'Ivoire"}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Kosovo', 'Costa Rica', 'Panama', 'Cayman Islands', 'Saint Lucia', 'Andorra', 'Saint Kitts and Nevis', 'Saudi Arabia', 'Bermuda', 'Slovenia', 'Grenada', 'Cape Verde'}
# Oxford/AstraZeneca:>>{'Tonga', 'Falkland Islands', 'Solomon Islands', 'Samoa', 'Sao Tome and Principe', 'Papua New Guinea', 'Montserrat', 'Uganda', 'Saint Vincent and the Grenadines', 'Angola', 'Eswatini', 'Madagascar', 'Lesotho', 'Togo', 'Fiji', 'Niue', 'Saint Helena', 'Mali', 'Liberia', 'Nigeria', 'Pitcairn', 'South Sudan', 'Nauru', 'Anguilla', 'Burkina Faso', 'Tuvalu', 'Kiribati', 'Vanuatu', 'Ethiopia', 'Democratic Republic of Congo'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Antigua and Barbuda'}
# CanSino, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Argentina'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Armenia', 'Zimbabwe'}
# Pfizer/BioNTech:>>{'New Caledonia', 'Cook Islands', 'Aruba', 'Kuwait', 'Gibraltar', 'Tokelau', 'Monaco', 'Turks and Caicos Islands', 'New Zealand'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Rwanda', 'Australia', 'Isle of Man', 'Sweden', 'Finland', 'Sint Maarten (Dutch part)', 'Guernsey', 'United Kingdom', 'Canada', 'Jersey', 'Japan'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Greece', 'Croatia', 'Spain', 'South Korea', 'Bulgaria', 'Poland', 'Netherlands', 'Czechia', 'Ireland', 'Estonia', 'Malta', 'Belgium', 'France', 'Romania', 'Iceland', 'Italy', 'Jamaica', 'Luxembourg', 'Germany', 'Portugal', 'Cyprus', 'Austria', 'Lithuania', 'Latvia'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Bahamas'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Bahrain', 'Mongolia', 'Serbia', 'Lebanon', 'Iraq', 'Montenegro', 'Jordan'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Bangladesh', 'Bhutan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Suriname', 'Barbados', 'Dominica', 'Maldives', 'Peru', 'Trinidad and Tobago'}
# Sinopharm/Beijing, Sputnik V:>>{'Kyrgyzstan', 'Belarus'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Niger', 'Sierra Leone', 'Myanmar', 'Namibia', 'Mozambique', 'Seychelles', 'Guinea-Bissau', 'Mauritania', 'Senegal', 'Brunei', 'Cameroon', 'Gambia', 'Belize'}
# Oxford/AstraZeneca, Sinovac:>>{'Timor', 'Benin'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Moldova', 'Bolivia', 'Morocco'}
# Moderna, Pfizer/BioNTech:>>{'Norway', 'Qatar', 'Switzerland', 'Israel', 'Bonaire Sint Eustatius and Saba', 'Faeroe Islands', 'Curacao', 'Liechtenstein'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Ukraine', 'Botswana'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Brazil'}
# Johnson&Johnson, Oxford/AstraZeneca:>>{'Malawi', 'British Virgin Islands', 'Haiti'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Cambodia', 'Somalia'}
# Covaxin, Oxford/AstraZeneca:>>{'Central African Republic'}
# Sinopharm/Beijing:>>{'Gabon', 'Chad', 'Equatorial Guinea'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Ecuador', 'Malaysia', 'Chile'}
# CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac, ZF2001:>>{'China'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Colombia'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Mauritius', 'Comoros'}
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Congo'}
# Abdala, Soberana02:>>{'Cuba'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'United States', 'Denmark'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Egypt', 'Djibouti', 'Laos'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'El Salvador', 'Dominican Republic', 'Thailand', 'Georgia'}
# Johnson&Johnson, Pfizer/BioNTech:>>{'South Africa', 'French Polynesia'}
# Oxford/AstraZeneca, Sputnik V:>>{'Nicaragua', 'Guyana', 'Kenya', 'Ghana'}
# Moderna:>>{'Wallis and Futuna', 'Greenland'}
# Moderna, Oxford/AstraZeneca:>>{'Guatemala'}
# Sputnik V:>>{'Guinea'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Honduras'}
# Pfizer/BioNTech, Sinovac:>>{'Turkey', 'Hong Kong'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca, Sputnik V:>>{'India'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Indonesia'}
# COVIran Barekat, Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Soberana02, Sputnik V:>>{'Iran'}
# QazVac, Sinopharm/Beijing, Sputnik V:>>{'Kazakhstan'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Philippines', 'Libya', 'Tunisia'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Macao'}
# CanSino, Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Zambia', 'Nepal'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'North Macedonia'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Northern Cyprus', 'Uruguay'}
# CanSino, Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik Light, Sputnik V:>>{'Palestine'}
# Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Paraguay'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Moderna, Pfizer/BioNTech, Sinovac:>>{'Singapore'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Slovakia'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Sri Lanka', 'Vietnam'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Sudan'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik Light, Sputnik V:>>{'Syria'}
# Medigen, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Taiwan'}
# Moderna, Oxford/AstraZeneca, Sinovac:>>{'Tajikistan'}
# Johnson&Johnson:>>{'Tanzania'}
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Turkmenistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Moderna, Oxford/AstraZeneca, Sputnik V, ZF2001:>>{'Uzbekistan'}
# Abdala, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'Venezuela'}
# Johnson&Johnson, Oxford/AstraZeneca, Sinovac:>>{'Yemen'}

# %%
import plotly.express as px
import plotly.offline as py

# %%
vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81554098-99aa-4217-944f-64135219771f" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81554098-99aa-4217-944f-64135219771f")) {
#                     Plotly.newPlot(
#                         '81554098-99aa-4217-944f-64135219771f',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "iso_code=%{location}<br>vaccines=%{z}", "locations": ["AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA",  ...
